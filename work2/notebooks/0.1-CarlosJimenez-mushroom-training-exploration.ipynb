# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, precision_score, recall_score
from functools import partial
import itertools

from tools.preprocess import load_datasets, preprocess_mushrooms_datasets
from tools.distance import ManhattanDistance, EuclideanDistance
from tools.voting import (
    MajorityClassVote,
    InverseDistanceWeightedVote,
    ShepardsWorkVote,
)
from tools.knn import KNNClassifier
from tools.metrics import cross_validate

import logging

logging.basicConfig(level=logging.ERROR, format="%(levelname)s - %(message)s")
logger = logging.getLogger()

# %%
train_dfs = load_datasets("datasetsCBR/mushroom/mushroom.fold.*.train.arff")
test_dfs = load_datasets("datasetsCBR/mushroom/mushroom.fold.*.test.arff")

print(f"\nNumber of training dataframes: {len(train_dfs)}")
print(f"Number of test dataframes: {len(test_dfs)}")
print()
train_dfs[0].head()
# Out:
# Number of training dataframes: 10
# Number of test dataframes: 10
#   cap-shape cap-surface cap-color bruises?  odor gill-attachment gill-spacing  \
# 0      b'f'        b'y'      b'y'     b'f'  b'f'            b'f'         b'c'
# 1      b'f'        b's'      b'b'     b't'  b'f'            b'f'         b'c'
# 2      b'x'        b'y'      b'g'     b't'  b'n'            b'f'         b'c'
# 3      b'x'        b'y'      b'e'     b't'  b'n'            b'f'         b'c'
# 4      b'x'        b's'      b'g'     b'f'  b'c'            b'f'         b'w'
#
#   gill-size gill-color stalk-shape  ... stalk-color-above-ring  \
# 0      b'b'       b'h'        b'e'  ...                   b'b'
# 1      b'b'       b'p'        b't'  ...                   b'w'
# 2      b'b'       b'w'        b'e'  ...                   b'w'
# 3      b'b'       b'n'        b't'  ...                   b'g'
# 4      b'n'       b'p'        b'e'  ...                   b'w'
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                   b'p'      b'p'       b'w'        b'o'      b'l'
# 1                   b'w'      b'p'       b'w'        b'o'      b'p'
# 2                   b'w'      b'p'       b'w'        b't'      b'p'
# 3                   b'g'      b'p'       b'w'        b'o'      b'p'
# 4                   b'w'      b'p'       b'w'        b'o'      b'p'
#
#   spore-print-color population habitat class
# 0              b'h'       b'v'    b'g'  b'p'
# 1              b'h'       b's'    b'g'  b'p'
# 2              b'w'       b'y'    b'p'  b'e'
# 3              b'k'       b'y'    b'd'  b'e'
# 4              b'k'       b's'    b'd'  b'p'
#
# [5 rows x 23 columns]

# %%
train_dfs = list(map(preprocess_mushrooms_datasets, train_dfs))
test_dfs = list(map(preprocess_mushrooms_datasets, test_dfs))

train_dfs[0].head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises?  odor  gill-attachment  \
# 0          2            3          9         0     2                1
# 1          2            2          0         1     2                1
# 2          5            3          3         1     5                1
# 3          5            3          2         1     5                1
# 4          5            2          3         0     1                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0             0          0           3            0  ...
# 1             0          0           7            1  ...
# 2             0          0          10            0  ...
# 3             0          0           5            1  ...
# 4             1          1           7            0  ...
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       0                       6          0           2
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 3                       3                       3          0           2
# 4                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat  class
# 0            1          2                  1           4        1      1
# 1            1          4                  1           3        1      1
# 2            2          4                  7           5        4      0
# 3            1          4                  2           5        0      0
# 4            1          4                  2           3        0      1
#
# [5 rows x 23 columns]

# %%
k_values = [1, 3, 5, 7]
distance_funcs = [ManhattanDistance(), EuclideanDistance()]
voting_funcs = [MajorityClassVote(), InverseDistanceWeightedVote(), ShepardsWorkVote()]

results = pd.DataFrame(
    columns=[
        "k",
        "distance_func",
        "voting_func",
        "f1_mean",
        "f1_std",
    ]
)
for k, distance_func, voting_func in itertools.product(
    k_values, distance_funcs, voting_funcs
):
    knn = KNNClassifier(
        k=k,
        distance_func=distance_func,
        voting_func=voting_func,
        weights=np.ones(len(train_dfs[0].columns) - 1),
    )
    scores = cross_validate(
        knn,
        train_dfs,
        test_dfs,
        target_col="class",
        score_func=partial(f1_score, average="weighted"),
    )
    results.loc[len(results)] = [
        k,
        distance_func.__class__.__name__,
        voting_func.__class__.__name__,
        scores.mean(),
        scores.std(),
    ]

results.sort_values(by="f1_mean", ascending=False)
# Out:
# /Users/zachparent/src/MAI/iml/work2/tools/voting.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   inverse_distances = [1 / (d**self.distance_weight) for d in distances]
# /Users/zachparent/src/MAI/iml/work2/tools/voting.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   inverse_distances = [1 / (d**self.distance_weight) for d in distances]
# /Users/zachparent/src/MAI/iml/work2/tools/voting.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   inverse_distances = [1 / (d**self.distance_weight) for d in distances]
# /Users/zachparent/src/MAI/iml/work2/tools/voting.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   inverse_distances = [1 / (d**self.distance_weight) for d in distances]
# /Users/zachparent/src/MAI/iml/work2/tools/voting.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   inverse_distances = [1 / (d**self.distance_weight) for d in distances]
# /Users/zachparent/src/MAI/iml/work2/tools/voting.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   inverse_distances = [1 / (d**self.distance_weight) for d in distances]
# /Users/zachparent/src/MAI/iml/work2/tools/voting.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   inverse_distances = [1 / (d**self.distance_weight) for d in distances]
# /Users/zachparent/src/MAI/iml/work2/tools/voting.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   inverse_distances = [1 / (d**self.distance_weight) for d in distances]
#     k      distance_func                  voting_func   f1_mean    f1_std
# 0   1  ManhattanDistance            MajorityClassVote  0.951025  0.028078
# 2   1  ManhattanDistance             ShepardsWorkVote  0.951025  0.028078
# 1   1  ManhattanDistance  InverseDistanceWeightedVote  0.951025  0.028078
# 6   3  ManhattanDistance            MajorityClassVote  0.931991  0.027454
# 12  5  ManhattanDistance            MajorityClassVote  0.931046  0.024939
# 18  7  ManhattanDistance            MajorityClassVote  0.924064  0.018326
# 5   1  EuclideanDistance             ShepardsWorkVote  0.904117  0.036884
# 3   1  EuclideanDistance            MajorityClassVote  0.904117  0.036884
# 4   1  EuclideanDistance  InverseDistanceWeightedVote  0.904117  0.036884
# 7   3  ManhattanDistance  InverseDistanceWeightedVote  0.898021  0.032240
# 8   3  ManhattanDistance             ShepardsWorkVote  0.887969  0.030184
# 9   3  EuclideanDistance            MajorityClassVote  0.880175  0.023838
# 15  5  EuclideanDistance            MajorityClassVote  0.873979  0.017794
# 21  7  EuclideanDistance            MajorityClassVote  0.873963  0.030472
# 13  5  ManhattanDistance  InverseDistanceWeightedVote  0.826843  0.022049
# 10  3  EuclideanDistance  InverseDistanceWeightedVote  0.818130  0.036362
# 14  5  ManhattanDistance             ShepardsWorkVote  0.811840  0.030338
# 11  3  EuclideanDistance             ShepardsWorkVote  0.807329  0.047674
# 19  7  ManhattanDistance  InverseDistanceWeightedVote  0.770021  0.031869
# 20  7  ManhattanDistance             ShepardsWorkVote  0.757371  0.041034
# 16  5  EuclideanDistance  InverseDistanceWeightedVote  0.710062  0.040389
# 17  5  EuclideanDistance             ShepardsWorkVote  0.692409  0.046207
# 22  7  EuclideanDistance  InverseDistanceWeightedVote  0.640166  0.049150
# 23  7  EuclideanDistance             ShepardsWorkVote  0.620490  0.036554

# %%
knn = KNNClassifier(
    k=1,
    distance_func=ManhattanDistance(),
    voting_func=MajorityClassVote(),
    weights=np.ones(len(train_dfs[0].columns) - 1),
)
scores = pd.DataFrame(
    columns=["precision", "recall", "f1"],
    data=cross_validate(
        knn,
        train_dfs,
        test_dfs,
        target_col="class",
        score_func=lambda actuals, preds: (
            precision_score(actuals, preds, average="weighted"),
            recall_score(actuals, preds, average="weighted"),
            f1_score(actuals, preds, average="weighted"),
        ),
    ),
)
scores
# Out:
#    precision  recall        f1
# 0   0.950041    0.95  0.949923
# 1   0.961084    0.96  0.960149
# 2   0.940000    0.94  0.940000
# 3   0.970141    0.97  0.969973
# 4   0.930256    0.93  0.930035
# 5   0.900880    0.90  0.900080
# 6   1.000000    1.00  1.000000
# 7   0.980909    0.98  0.980057
# 8   0.960000    0.96  0.960000
# 9   0.920800    0.92  0.920032

# %% [markdown]
# # Pre-Analysis

# %%
preds = []
actuals = []

for train_df, test_df in zip(train_dfs, test_dfs):
    decision_tree = DecisionTreeClassifier()
    decision_tree.fit(train_df.drop("class", axis=1), train_df["class"])
    preds.extend(decision_tree.predict(test_df.drop("class", axis=1)))
    actuals.extend(test_df["class"])

print(classification_report(actuals, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       494
#            1       0.93      0.93      0.93       506
#
#     accuracy                           0.93      1000
#    macro avg       0.93      0.93      0.93      1000
# weighted avg       0.93      0.93      0.93      1000

# %%
feature_importances = pd.DataFrame(
    {
        "feature": train_dfs[0].drop("class", axis=1).columns,
        "importance": decision_tree.feature_importances_,
        "index": range(len(decision_tree.feature_importances_)),
    }
)
top_5_features = feature_importances.sort_values("importance", ascending=False).head(5)
print("Top 5 features:")
top_5_features
# Out:
# Top 5 features:
#          feature  importance  index
# 8     gill-color    0.372931      8
# 4           odor    0.306495      4
# 6   gill-spacing    0.135556      6
# 7      gill-size    0.077070      7
# 10    stalk-root    0.038873     10

# %%
pd.plotting.scatter_matrix(
    pd.concat(train_dfs + test_dfs)[top_5_features.feature.values.tolist() + ["class"]],
    figsize=(12, 12),
)
plt.show()

# %%
import seaborn as sns

top_5_features_and_class = top_5_features["feature"].tolist() + ["class"]
corr_matrix = pd.concat(train_dfs + test_dfs)[top_5_features_and_class].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", vmin=-1, vmax=1, center=0)
plt.title("Correlation Heatmap of Top 5 Features")
plt.show()
